# %% [markdown]
# <a href="https://colab.research.google.com/github/fierrofloresambarh-prog/derecho-a-examen/blob/main/derecho_a_examen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
total_clase=float(input("ingrese total de clases"))
clases_asistidas=float(input("ingrese clases asistidas"))

aistencia=(clases_asistidas*100/total_clase)

if aistencia>=80:
   print("tiene derecho a examen")
else:
   print("no tiene derecho a examen")
# Out:
# ingrese total de clases120
# ingrese clases asistidas50
# no tiene derecho a examen

# %%
total_clase=float(input("ingrese total de clases"))
clases_asistidas=float(input("ingrese clases asistidas"))

aistencia=(clases_asistidas*100/total_clase)

if aistencia>=80:
   print("tiene derecho a examen")
else:
   print("no tiene derecho a examen")
# Out:
# ingrese total de clases100
# ingrese clases asistidas100
# tiene derecho a examen

# %% [markdown]
# ![texto del vínculo](https:///raw.githubusercontent.com/fierrofloresambarh-prog/derecho-a-examen/refs/heads/main/derecho%20a%20examen.png)
